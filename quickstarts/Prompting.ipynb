# %% [markdown]
# # Primera parte (variables + if\else)

# %%
'''

Para entnder la funcion de simbolos matematicos

> = mayor que
< = menor que
>= = mayor o igual que
<= = menor o igual que
== = igual que
!= = diferente que

'''

nombre = 'Luis'
nombre1 = 'angelo'
edad = 23
hobby = 'motos'
#_motos = 7

print('Buenas noches!')
print('Como te llamas?', nombre)
print('Que edad tienes?', edad)
print('Que hobby te gusta?', hobby)

if edad >= 18:
    print('Veo que ya eres adulto!')
else:
    print('Aun te falta algo por crecer')

if nombre == nombre1:
  print('Eres la misma persona!')
else:
  print('Te nombre no me es familiar')

  '''
  Esto me ayuda a entender la
  sintaxis y uso de las condicionales
  '''
# Out:
# Buenas noches!
# Como te llamas? Luis
# Que edad tienes? 23
# Que hobby te gusta? motos
# Veo que ya eres adulto!
# Te nombre o me es familiar

# %%
Banquete = 'Muchas comidas'
Comida_fav = 'Pescado con brocoli al vapor'
hobby = 'motos'
numero_motos = 7

'''
Aqui aprendo como usar varias
condinciones en una sola linea
'''

print('Buenas noches!')

print('Cual es la comida que mas te gusta?', Banquete)

if Comida_fav != 'Muchas comidas':
  print('Tienes algun plato mas especifico?')
else:
  print('Ohh, si que llevas buenos gustos')

if Comida_fav == 'Pescado con brocoli al vapor':
  print(Comida_fav)
  print('Ohh, si que llevas buenos gustos')

print('Cuantas motos has tenido en total?', numero_motos)

if numero_motos >= 7:
  print('Es un buen numero de motos para tu edad!Habras tenido muchas experiencias')
else:
  print('Buen numero pero o creo que sea cierto')
# Out:
# Buenas noches!
# Cual es la comida que mas te gusta? Muchas comidas
# Tienes algun plato mas especifico?
# Pescado con brocoli al vapor
# Ohh, si que llevas buenos gustos
# Cuantas motos has tenido en total? 7
# Es un buen numero de motos para tu edad! Habras tenido muchas experiencias

# %% [markdown]
# # Segunda parte (Condicionales + elif)

# %%
'''
usando condicion (elif)

'''

Comida_fav = 'pescado al vapor'
Moto = 'suzuki'
hooby = 'pista y campo'
distancia = 25

print('Que te gustaria comer?', Comida_fav)

if Comida_fav == 'camarones':
  print('Son muy buenos pero se debe tener cuidado')
elif Comida_fav == 'pasta':
  print('Eso es!, tremendo para recuperar')
elif Comida_fav == 'arroz blanco':
  print('Buena fuente de fibra!')
elif Comida_fav == 'omelette':
  print('Eso si es un desayuno!')
elif Comida_fav := 'camarones al ajillo':
  print('Eso si se acerca a lo que prefieres')
else:
  print('tendre que escuchar mas de ti')

print('Y que mas te gusta?')
print(hooby)

if hooby == 'motos':
  print('Tambien me gustan las motos')
elif hooby == 'carros':
  print('Caro, pero entendible')
elif hooby := 'correr':
  print('Eso si esta dentro de tus posibilidades!')
elif hooby == 'ciclismo':
  print('esto tambien se alinea con tus preferencias!')
else:
  print('Todo hooby puede ayudarte a despejar la mente!')

  '''
  Con elif puedes realizar condicones
  casi infinitas.
  Evalúa de arriba hacia abajo

  Ejecuta solo la primera condición verdadera

  Ignora el resto
  '''
# Out:
# Que te gustaria comer? pescado al vapor
# Eso si se acerca a lo que prefieres
# Y que mas te gusta?
# pista y campo
# Eso si esta dentro de tus posibilidades!

# %% [markdown]
# # Tercera parte (Operadores logicos {And, Or, Not})

# %%
'''
Codigo para determinar si una
persona puede ser aprobada para
la compra de una moto nueva
'''

edad = 17
credit_score = 0
licencia = True
pronto = 1001

if edad >= 18 and credit_score >= 700 and licencia == True and pronto <= 1000:
  print('Aprobacion inmediata. Que moto te interesa?')
else:
  print('Lo sentimos, no cumples con los requisitos')

'''
🔹 Para encadenar condiciones
anidadas (if dentro de if)
'''

if credit_score <= 700:
  if licencia == True:
    print('Aprobacion inmediata. Que moto te interesa?')
  else:
    print('Debes al menos proveer una licencia')
else:
  print('Lo sentimos, no cumples con los requisitos')

'''
🔹 elif (else if)
En vez de escribir muchos if,
puedes usar elif.
'''

pronto1 = int((input)('Monto de enganche'))

if pronto1 == 1000:
  print('Reduces 60usd al pago mensual')
elif pronto1 == 900:
  print('Reduces 45usd al pago mensual')
elif pronto1 == 1500:
  print('Reduces 90usd al pago mensual')
elif pronto1 == 2000:
  print('Reduces 120usd al pago mensual')
elif pronto1 == 2500:
  print('Reduces 150usd al pago mensual')
elif pronto1 == 3000:
  print('Reduces 180usd al pago mensual')
elif pronto1 == 3500:
  print('Reduces 210usd al pago mensual')
else:
  print('Pago se que da igual')

'''
Codigo optimizado
'''

pronto1 = int(input('Monto de enganche: '))

descuentos = {
    900: 45,
    1000: 60,
    1500: 90,
    2000: 120,
    2500: 150,
    3000: 180,
    3500: 210
}

if pronto1 in descuentos:
    print(f"Reduces {descuentos[pronto1]} usd al pago mensual")
else:
    print("Pago se queda igual")
# Out:
# Lo sentimos, no cumples con los requisitos
# Aprobacion inmediata. Que moto te interesa?
# Monto de enganche3000
# Reduces 180usd al pago mensual
# Monto de enganche: 2500
# Reduces 150 usd al pago mensual

# %%
'''
Siguiendo con operadores
logicos
'''

'''
Operador
(And)
Se cumple solo si TODAS las condiciones son verdaderas
'''
edad = 23
honestidad = True
Comida_fav = 'Pescado'
dia_festivo = False
dia_actual = 'Thanksgiving'

print('Cual estu edad real?', edad)

if edad <= 23 and honestidad == True:
    print('Jumm, info correcta')
else:
    print('No estas siendo honesto')
'''
operador
(Or)
Se cumple si al menos una
condición es verdadera.
'''
print('Que te gusta comer cuando sales?', Comida_fav)

if Comida_fav == 'mariscos' or Comida_fav == 'Pescado':
  print('Esa es!!, lo mejor para tu condicion')
else:
  print('Buena fuente de omega')

'''
Operador
(Not)
Invierte el valor lógico.
'''
print('Que dia es hoy?', dia_actual)

if not dia_festivo:
  print('Ohh pues te toca lo mejor, compartir en familia. Pasala bien!')
# Out:
# Cual estu edad real? 23
# Jumm, info correcta
# Que te gusta comer cuando sales? Pescado
# Esa es!!, lo mejor para tu condicion
# Que dia es hoy? Thanksgiving
# Ohh pues te toca lo mejor, compartir en familia. Pasala bien!

# %% [markdown]
# # Cuarta parte (loop {for, while} + entrada de datos)

# %%
from typing import Counter
'''
Loops
(for, while)
cómo repetir acciones, recorrer listas y
construir lógica más compleja.
'''

'''
Este es while
'''

Meta = 50000
Alcanzado = 42500
Asignado = 300

while Meta > Alcanzado:
  print('Llevas', Alcanzado)

  Alcanzado += Asignado
print('Has llegado a tu meta!', Meta)
# Out:
# Llevas 42500
# Llevas 42800
# Llevas 43100
# Llevas 43400
# Llevas 43700
# Llevas 44000
# Llevas 44300
# Llevas 44600
# Llevas 44900
# Llevas 45200
# Llevas 45500
# Llevas 45800
# Llevas 46100
# Llevas 46400
# Llevas 46700
# Llevas 47000
# Llevas 47300
# Llevas 47600
# Llevas 47900
# Llevas 48200
# Llevas 48500
# Llevas 48800
# Llevas 49100
# Llevas 49400
# Llevas 49700
# Has llegado a tu meta! 50000

# %%
'''
Usando while con input
'''
Meta = 50000
Alcanzado = 0
Asignado_Mes = 300

Meta = int(input('Dime tu meta:'))
Alcanzado = int(input('Dime cuanto llevas:'))
Asignado_Mes = int(input('Dime cuanto vas a asignar al mes:'))

while Alcanzado < Meta:
  print('Te faltan:', Meta - Alcanzado)
  Alcanzado += Asignado_Mes


  if Alcanzado >= Meta:
    print('Y has llegado a tu meta!', Meta)
    break
# Out:
# Dime tu meta:5000
# Dime cuanto llevas:666
# Dime cuanto vas a asignar al mes:300
# Te faltan: 4334
# Te faltan: 4034
# Te faltan: 3734
# Te faltan: 3434
# Te faltan: 3134
# Te faltan: 2834
# Te faltan: 2534
# Te faltan: 2234
# Te faltan: 1934
# Te faltan: 1634
# Te faltan: 1334
# Te faltan: 1034
# Te faltan: 734
# Te faltan: 434
# Te faltan: 134
# Y has llegado a tu meta! 5000
